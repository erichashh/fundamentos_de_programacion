# %% [markdown]
# Ejercicio 3 detectar el error
# El error es que  12 se resta directamente como dinero, en lugar de representar el 12% del precio.
#
# Lo corrijo:

# %%
import pdb

precio=45
descuento=12

pdb.set_trace()
descuento = precio * (descuento / 100)
total = precio - descuento

print(f"Total: {total:.2f}")
# Out:
# Running cells with 'Python 3.14.6' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# El total nos queda que es: 39.60
